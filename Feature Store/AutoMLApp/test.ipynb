# %%
from databricks.sdk import WorkspaceClient
from databricks.sdk.service import jobs

w = WorkspaceClient()

# %%
w.jobs.run_now(
  job_id=276534878518989,
  job_parameters={
    'exp_name': 'test_automl_app',
    'pct_train': 0.7,
    'n_exp': 1,
    'min_depth': 1,
    'max_depth': 10,
    'min_learning_rate': 0.01,
    'max_learning_rate': 0.40
  }
)
