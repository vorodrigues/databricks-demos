# %% [markdown]
# Demo configuration.
#
# If you wish to install the demo using another schema and database, it's best to do it with dbdemos:
#
# `dbdemos.install('xxx', catalog='xx', schema='xx')`

# %%
catalog = "vr_demo"
dbName = db = "fine_tuning"
volume_name = "raw_training_data"
